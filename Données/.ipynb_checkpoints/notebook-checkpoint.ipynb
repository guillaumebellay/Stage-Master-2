# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns

from MissingValuesHandler.missing_data_handler import RandomForestImputer

from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif
from sklearn.compose import ColumnTransformer
from imblearn.pipeline import Pipeline
from sklearn.inspection import permutation_importance
from imblearn.over_sampling import SMOTE

from scipy.stats import chi2_contingency

from lightgbm import LGBMClassifier
from sklearn.ensemble import ExtraTreesClassifier, GradientBoostingClassifier, RandomForestClassifier
import shap

from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score

from flaml import AutoML
from tpot import TPOTClassifier

# %% [markdown]
# ### Chargement des données

# %%
data = pd.read_csv('RecodedBase.txt', sep="\t", index_col="IDsujet")
data.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Sélection des variables

# %%
liste_var_drop = ['no_etude_1', 'OrientSex', 'prof_duree_non_emploi', 'prof_code_dernier_poste', 'prof_duree',
                  'prof_benev', 'prof_duree_benev', 'prof_age_prem_emploi', 'prof_duree_emploi', 'prof_duree_totale',
                  'revenu_perso','men_sujet', 'men_epoux', 'men_fratrie_nb', 'men_autrefam', 'men_autrepers', 'men_autrepers2',
                  'men_enfants_nb','H1_annee', 'H1_duree', 'H2_annee', 'H2_duree', 'H3_annee', 'H3_duree', 'H4_annee',
                  'H4_duree','H5_annee','H5_duree', 'H1_age','age_patho', 'H_nbr_total', 'H_duree_totale', 'H_suivi_ext',
                  'med1_annee', 'med1_duree','med2_annee','med2_duree', 'med3_annee', 'med3_duree', 'med4_annee',
                  'med4_duree', 'med5_annee', 'med5_duree','med6_annee', 'med6_duree', 'mv1_annee', 'mv1_duree', 'mv2_annee',
                  'mv2_duree', 'mv3_annee', 'mv3_duree','mv4_annee', 'mv4_duree', 'mv5_annee', 'mv5_duree', 'mv6_annee',
                  'mv6_duree', 'sep_parent', 'sep_age','divorce_age', 'adopte_age', 'fam_accueil_age', 'abus', 'abus1_type',
                  'abus1_age_2', 'abus1_age3','abus1_age4', 'abus1_ss', 'abus2_type', 'abus2_age', 'abus2_age_2',
                  'abus2_age_3', 'abus2_age_4', 'abus2_ss','abus3_type', 'abus3_age', 'abus3_age_2', 'abus3_ss', 'fam_15u', 
                  'enfant_1_SEXE',
                  'enfant_1_AGE', 'enfant_1_B', 'enfant_1_DEP', 'enfant_1_MA', 'enfant_1_SZ', 'enfant_1_SUI', 'enfant_1_T_SUI',
                  'enfant_1_ALC', 'enfant_1_AD', 'enfant_1_ALZ', 'enfant_1_DOC', 'enfant1_1_JEU', 'enfant13_1_AucunePATHO',
                  'enfant_2_SEXE', 'enfant_2_AGE', 'enfant_2_B', 'enfant_2_DEP', 'enfant_2_MA', 'enfant_2_SZ', 'enfant_2_SUI',
                  'enfant_2_T_SUI', 'enfant_2_ALC', 'enfant_2_AD', 'enfant_2_ALZ', 'enfant_2_DOC', 'enfant_2_JEU',
                  'enfant_2_AucunePATHO', 'enfant_3_SEXE', 'enfant_3_AGE', 'enfant_3_B', 'enfant_3_DEP', 'enfant_3_MA',
                  'enfant_3_SZ','enfant_3_SUI', 'enfant_3_T_SUI', 'enfant_3_ALC', 'enfant_3_AD', 'enfant_3_ALZ',
                  'enfant_3_DOC','enfant_3_JEU', 'enfant_3_AucunePATHO', 'enfant_4_SEXE', 'enfant_4_AGE', 'enfant_4_B',
                  'enfant_4_DEP', 'enfant_4_MA', 'enfant_4_SZ', 'enfant_4_SUI', 'enfant_4_T_SUI', 'enfant_4_ALC',
                  'enfant_4_AD', 'enfant_4_ALZ', 'enfant_4_DOC', 'enfant_4_JEU', 'enfant_4_AucunePATHO', 'enfant_5_SEXE',
                  'enfant_5_AGE', 'enfant_5_B', 'enfant_5_DEP','enfant_5_MA', 'enfant_5_SZ', 'enfant_5_SUI', 'enfant_5_T_SUI',
                  'enfant_5_ALC', 'enfant_5_AD','enfant_5_ALZ', 'enfant_5_DOC', 'enfant_5_JEU', 'enfant_5_AucunePATHO',
                  'Cotationevitante',
                  'CotationDependante', 'CotationObsessiveCompulsive', 'CotationPassiveAgressive', 'CotationDepressive',
                  'CotationParanoide', 'CotationSchizotypique', 'CotationSchizoide', 'CotationHistrionique',
                  'CotationNarcissique', 'CotationBorderline', 'CotationTrConduites', 'CotationAntisociale', 'CotationNS',
                  'NbDXClusterA', 'NbDXClusterB', 'NbDXClusterC', 'NbDxAutres', 'NbTOTALdxAXEII',
                  'Trouble_perso_passive_agressive', 'item25_evitante', 'item26_evitante', 'item27_evitante',
                  'item28_evitante', 'item29_evitante', 'item30_evitante', 'item31_evitante', 'item32SEUILevitante',
                  'item33_dependante', 'item34_dependante', 'item35_dependante', 'item36_dependante', 'item37_dependante',
                  'item38_dependante', 'item39_dependante', 'item40_dependante', 'item41SEUIldependante',
                  'item42_ObsessiveCompulsive', 'item43_ObsessiveCompulsive', 'item44_ObsessiveCompulsive',
                  'item45_ObsessiveCompulsive', 'item46_ObsessiveCompulsive', 'item47_ObsessiveCompulsive',
                  'item48_ObsessiveCompulsive', 'item49_ObsessiveCompulsive', 'itam50SEUILObsessiveCompulsive',
                  'item51_PassiveAgressive', 'item52_PassiveAgressive', 'item53_PassiveAgressive', 'item54_PassiveAgressive',
                  'item55_PassiveAgressive', 'item56_PassiveAgressive', 'item57_PassiveAgressive',
                  'item58SEUILPassiveAgressive', 'item59_depressive', 'item60_depressive', 'item61_depressive',
                  'item62_depressive', 'item63_depressive', 'item64_depressive', 'item65_depressive','item66SEUILdepressive',
                  'item67_paranoide', 'item68_paranoide', 'item69_paranoide', 'item70_paranoide','item71_paranoide',
                  'item72_paranoide', 'item73_paranoide', 'item74SEUILparanoide', 'item75_schizotypique','item76_schizotypique',
                  'item77_schizotypique', 'item78_schizotypique', 'item79_schizotypique','item80_schizotypique',
                  'item81_schizotypique', 'item82_schizotypique', 'item83_schizotypique','item84SEUILschizotypique',
                  'item85_schizoide', 'item86_schizoide', 'item87_schizoide', 'item89_schizoide','item90_schizoide',
                  'item91_schizoide', 'item92SEUILschizoide', 'item93_histrionique', 'item94_histrionique',
                  'item95_histrionique', 'item96_histrionique', 'item97_histrionique', 'item98_histrionique', 
                  'item99_histrionique', 'item100_histrionique', 'item101SEUILhistrionique', 'item102_narcissique',
                  'item103_narcissique', 'item104_narcissique', 'item105_narcissique', 'item106_narcissique',
                  'item107_narcissique', 'item108_narcissique', 'item109_narcissique', 'item110_narcissique',
                  'item111SEUILnarcissique', 'item112_borderline', 'item113_borderline', 'item114_borderline',
                  'item115_borderline', 'item116_borderline', 'item117_borderline', 'item118_borderline',
                  'item119_borderline', 'item120_borderline', 'item121SEUILborderline', 'item122_TrConduites',
                  'item123_TrConduites', 'item124_TrConduites', 'item125_TrConduites', 'item126_TrConduites',
                  'item127_TrConduites', 'item128_TrConduites', 'item129_TrConduites', 'item130_TrConduites',
                  'item131_TrConduites', 'item132_TrConduites', 'item133_TrConduites', 'item134_TrConduites',
                  'item135_TrConduites', 'item136_TrConduites', 'item137_TrConduites', 'item138SEUILTrConduites',
                  'item139_antisociale', 'item140_antisociale', 'item141_antisociale', 'item142_antisociale',
                  'item143_antisociale', 'item144_antisociale', 'item145_antisociale', 'item146_antisociale',
                  'item147SEUILantisociale', 'item148_persoNS', 'TSpremiere', 'TSderniere', 'TSsevere', 'Methode_deces1',
                  'Methode_deces2', 'Methode_deces3', 'ScoreTotalSOGS', 'billetv', 'casinov', 'bingov', 'cartesv', 'coursev',
                  'boursev', 'machinv', 'jaddv', 'desv', 'sportv', 'autjeuv', 'billetm', 'casinom', 'bingom', 'cartesm',
                  'coursem', 'boursem', 'machinm', 'jaddm', 'desm', 'sportm', 'autjeum', 'q2a_1_R_sur_S', 'q2a_2_R_sur_S',
                  'q2a_3_R_sur_S', 'q2a_4_R_sur_S', 'q2a_5_R_sur_S', 'q3_parenpbj', 'q4_refaire', 'q5_menti', 'q6_pbjeu',
                  'q7_pariplus', 'q8_critique', 'q9_coupable', 'q10_arretnon', 'q11_cacher', 'q12_dispute', 'q13_dispjeu',
                  'q14_emprunt', 'q15_absence', 'q16_emprjeu', 'q17a', 'q17b', 'q17c', 'q17d', 'q17e', 'q17f', 'q17g', 'q17h',
                  'q17i', 'q17j', 'q17k', 'q17l']

data.drop(liste_var_drop, axis=1, inplace=True)

# %% [markdown]
# ### Nettoyage des données

# %%
# suppression des individus appartenant au groupe 999
data['GroupeAppartenance'].fillna(999,inplace=True)
data.drop(index=data[data['GroupeAppartenance'] == 999].index, inplace=True)
data.reset_index(drop=True, inplace=True)

# %%
# remplacement des valeurs aberrantes par NAN
data['med1_prise'].replace(2,np.NAN, inplace=True)
data['med2_code'].replace(156,np.NAN, inplace=True)
data['med3_prise'].replace(8,np.NAN, inplace=True)
data['med4_prise'].replace(156,np.NAN, inplace=True)
data['med6_prise'].replace(2,np.NAN, inplace=True)
data['mv1_prise'].replace(2,np.NAN, inplace=True)
data['mv2_code'].replace(929,np.NAN, inplace=True)
data['mv2_prise'].replace(2,np.NAN, inplace=True)
data['mv3_prise'].replace(2,np.NAN, inplace=True)
data['mv4_prise'].replace(2,np.NAN, inplace=True)
data['mv5_prise'].replace(2,np.NAN, inplace=True)
data['mv6_prise'].replace(2,np.NAN, inplace=True)
data['DEPfrereC'].replace(3,np.NAN, inplace=True)
data['DEPsoeurC'].replace(3,np.NAN, inplace=True)
data['DEPsoeurC'].replace(4,np.NAN, inplace=True)
data['DEPsoeurC'].replace(5,np.NAN, inplace=True)
data['DEPsoeurP'].replace(3,np.NAN, inplace=True)
data['MA_frereC'].replace(3,np.NAN, inplace=True)
data['MA_soeurC'].replace(5,np.NAN, inplace=True)
data['T_SUIfrereP'].replace(2,np.NAN, inplace=True)
data['T_SUIsoeurC'].replace(3,np.NAN, inplace=True)
data['ALCfrereC'].replace(3,np.NAN, inplace=True)
data['ALCfrereC'].replace(6,np.NAN, inplace=True)
data['ALCfrereP'].replace(6,np.NAN, inplace=True)
data['ALCfrereP'].replace(5,np.NAN, inplace=True)
data['ALCsoeurC'].replace(6,np.NAN, inplace=True)
data['DXaxeIVIE_00'].replace(243,np.NAN, inplace=True)
data['DXaxeIVIE_04'].replace(233,np.NAN, inplace=True)
data['DXaxeII_01'].replace(0,np.NAN, inplace=True)
data['DXaxeII_02'].replace(0,np.NAN, inplace=True)
data['DXaxeII_03'].replace(0,np.NAN, inplace=True)
data['DXaxeII_04'].replace(0,np.NAN, inplace=True)
data['DXaxeII_05'].replace(0,np.NAN, inplace=True)

# %%
# Si un individu ne prend pas de médicament, on remplace le type de médicament par "aucun" : 0
data.loc[data[data['med1_prise'].isin([888,999])].index, "med1_code"] = 0
data.loc[data[data['med2_prise'].isin([888,999])].index, "med2_code"] = 0
data.loc[data[data['med3_prise'].isin([888,999])].index, "med3_code"] = 0
data.loc[data[data['med4_prise'].isin([888,999])].index, "med4_code"] = 0
data.loc[data[data['med5_prise'].isin([888,999])].index, "med5_code"] = 0
data.loc[data[data['med6_prise'].isin([888,999])].index, "med6_code"] = 0
data.loc[data[data['mv1_prise'].isin([888,999])].index, "mv1_code"] = 0
data.loc[data[data['mv2_prise'].isin([888,999])].index, "mv2_code"] = 0
data.loc[data[data['mv3_prise'].isin([888,999])].index, "mv3_code"] = 0
data.loc[data[data['mv4_prise'].isin([888,999])].index, "mv4_code"] = 0
data.loc[data[data['mv5_prise'].isin([888,999])].index, "mv5_code"] = 0
data.loc[data[data['mv6_prise'].isin([888,999])].index, "mv6_code"] = 0

data.drop(['med1_prise', 'med2_prise', 'med3_prise', 'med4_prise', 'med5_prise', 'med6_prise', 'mv1_prise', 'mv2_prise',
          'mv3_prise', 'mv4_prise', 'mv5_prise', 'mv6_prise'], axis=1, inplace=True)

# %%
# un individu dont la/le mère/père est décédé ne vit pas avec sa/son mère/père
data.loc[data[data['mere_vie'] == 0].index, 'men_mere'] = 0
data.loc[data[data['pere_vie'] == 0].index, 'men_pere'] = 0
# un individu qui vit avec sa/son mère/père a donc sa/son mère/père vivant
data.loc[[221, 224, 272, 362, 366, 371, 379, 381, 419, 469],'mere_vie'] = 1
data.loc[[221, 272, 294, 469],'pere_vie'] = 1

# %%
# un individu qui ne travaille pas est donc 'sans emploi'
data.loc[data[data['prof_emploi'] == 0].index,'prof_code'] = 14
data.drop('prof_emploi', axis=1, inplace=True)

# %%
# modification enfants_nb, fratrie_nb, adopte, divorce, fam_accueil et separation
data['enfants_nb'].replace(999,0,inplace=True)
data['enfants_nb'].replace(888,0,inplace=True)
data['enfants_nb'].fillna(0,inplace=True)
data['fratrie_n_b'].replace(999,0,inplace=True)
data['fratrie_n_b'].replace(888,0,inplace=True)
data['fratrie_n_b'].fillna(0,inplace=True)
data['adopte'].replace(999,0,inplace=True)
data['adopte'].replace(888,0,inplace=True)
data['fam_accueil'].replace(999,0,inplace=True)
data['fam_accueil'].replace(888,0,inplace=True)
data['divorce'].replace(999,0,inplace=True)
data['divorce'].replace(888,0,inplace=True)
data['separation'].replace(999,0,inplace=True)
data['separation'].replace(888,0,inplace=True)

# %%
# modifications valeurs men (individu par individu)
data.loc[[0, 1, 3, 4, 5, 9, 10, 11, 12, 14, 15, 17, 18, 42, 72, 74, 81, 82, 83, 85, 86, 88, 89, 92, 94, 95, 97, 99,
          100, 103, 107, 108, 110, 119, 122, 125,
          128, 131, 177, 179, 180, 182, 184, 185, 188, 189, 190, 191, 192, 193, 194, 196, 197, 198, 213, 228,
          250, 339, 340, 341, 342, 343, 345, 347, 500, 505,
          506, 507, 510, 511, 513, 514, 515, 521, 522, 526, 528, 530, 531, 532], 'men_conjoint'] = 0

data.loc[[2, 6, 7, 8, 13, 16, 19, 71, 73, 75, 76, 77, 78, 79, 80, 84, 87, 90, 91, 93, 96, 98, 101, 102, 104, 105, 106, 109,
          111, 181, 187, 195, 230, 245, 246, 247, 248, 249, 251, 342, 346, 364, 498, 499, 501, 508, 509, 512, 518, 523,
          525, 527, 529], 'men_conjoint'] = 1

data.loc[[0, 1, 2, 3, 6, 7, 8, 13, 15, 16, 17, 18, 19, 42, 71, 73, 75, 76, 77, 78, 79, 80, 82, 83, 84, 85, 86, 87, 88, 89,
          90, 91, 92, 93, 94, 96, 98, 99, 100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 128,
          131, 180, 181,
          182, 187, 188, 191, 192, 193, 194, 195, 197, 198, 228, 230, 245, 246, 247, 248, 249, 250, 251, 339, 340, 341,
          342, 343, 345, 346, 347, 364, 498, 499, 500, 501, 505, 506, 507, 508, 509, 512, 513, 514, 515, 518, 521, 523, 526,
          527, 528, 530, 531, 532], 'men_mere'] = 0

data.loc[[119, 122, 125], 'men_mere'] = 1

data.loc[[0, 1, 2, 3, 6, 7, 8, 13, 15, 16, 17, 18, 19, 42, 71, 73, 75, 76, 77, 78, 79, 80, 82, 83, 84, 85, 86, 87, 88, 89,
          90, 91, 92, 93, 94, 96, 98, 99, 100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 128,
          131, 180, 181,
          182, 187, 188, 191, 192, 193, 194, 195, 197, 198, 228, 230, 245, 246, 247, 248, 249, 250, 251, 339, 340, 341,
          342, 343, 345, 346, 347, 364, 498, 499, 500, 501, 505, 506, 507, 508, 509, 512, 513, 515, 518, 521, 523, 527,
          528, 530, 532], 'men_pere'] = 0

data.loc[[119, 122, 125], 'men_pere'] = 1

data.loc[[0, 1, 2, 3, 6, 7, 8, 13, 15, 16, 17, 18, 19, 42, 71, 73, 75, 76, 77, 78, 79, 80, 82, 83, 84, 85, 86, 87, 88, 89,
          90, 91, 92, 93, 94, 96, 98, 99, 100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 128, 131, 180, 181,
          182, 187, 188, 191, 192, 193, 194, 195, 197, 198, 228, 230, 245, 246, 247, 248, 249, 250, 251, 339, 340, 341,
          342, 343, 345, 346, 347, 364, 372, 498, 499, 500, 501, 505, 506, 507, 508, 509, 510, 512, 513, 514, 515, 518, 521,
          522, 523, 525, 526, 527, 528, 529, 530, 531, 532], 'men_fratrie'] = 0

data.loc[[42, 119, 122, 125, 126, 128, 345], 'men_fratrie'] = 1

data.loc[[0, 1, 3, 4, 5, 7, 9, 10, 11, 12, 14, 15, 16, 17, 18, 19, 42, 71, 72, 74, 75, 76, 79, 80, 81, 82, 83, 84, 85, 86,
          88, 89, 92, 93, 94, 95, 97,
          99, 100, 102, 103, 106, 107, 108, 109, 110, 119, 122, 125, 128, 177, 179, 182, 184, 185, 187, 188, 189, 190,
          191, 192, 193, 194, 197, 198, 213,
          228, 230, 250, 339,
          340, 341, 342, 343, 345, 347, 499, 500, 505, 506, 507, 508, 513, 515, 518, 523, 528, 530, 532], 'men_enfants'] = 0

data.loc[[2, 6, 8, 13, 73, 77, 78, 87, 90, 91, 99, 101, 105, 107, 108, 111, 195, 196, 245, 246, 247, 248,
          249, 251, 346, 364,
          372, 498, 501, 509, 510, 512, 514, 521, 522, 525, 527], 'men_enfants'] = 1

data.loc[[0, 1, 3, 15, 17, 18, 42, 82, 83, 85, 86, 88, 89, 92, 94, 99, 100, 103, 107, 108, 110, 128, 182, 188, 191,
          192, 193, 194, 197, 198, 228, 250, 339, 340, 341, 342, 343, 345, 347, 500, 505, 506, 507, 513, 515,
          528, 530, 532], 'men_total'] = 1

data.loc[[7, 16, 19, 48, 71, 75, 76, 79, 80, 84, 93, 102, 106, 109, 187, 230, 345, 499, 508, 510, 518, 523], 'men_total'] = 2

data.loc[[87, 91, 99, 101, 105, 107, 108, 111, 364, 512, 514, 521, 522, 525], 'men_total'] = 3

data.loc[[2, 6, 73, 77, 90, 119, 125, 195, 246, 247, 248, 251, 342, 346, 498, 509, 527], 'men_total'] = 4

data.loc[[8, 42, 78, 126, 245, 249, 501], 'men_total'] = 5

data.loc[[13], 'men_total'] = 6

data.loc[[128], 'men_total'] = 7

# %%
data.loc[[42, 119, 122, 125], 'habite'] = 2
data.loc[[76, 230], 'habite'] = 3
data.loc[128, 'habite'] = 6
data.loc[[119, 122, 125, 285], 'enfants_b'] = 0
data.loc[125, 'mere_vie'] = 1

# %%
# remplacer 222, 888 et 999 par Nan
data = data.replace(222, np.NAN).replace(888, np.NAN).replace(999, np.NAN)

# %%
# suppression des colonnes avec seulement des valeurs nulles
variables_nan = list(data.columns[data.isna().all()])
data.drop(variables_nan, axis=1, inplace=True)

# %% [markdown]
# ### Imputation des données manquantes pour les 125 premières variables et les variables fardeau

# %% [markdown]
# MissingValuesHandler utilise l'algorithme random forest pour remplacer les valeurs manquantes.
#
# Le type de Random Forest (régression ou classification) est traité automatiquement. Si la variable à prédire est numérique, alors on utilise RandomForestRegressor et si elle est catégorielle alors on utilise RandomForestClassifier.
#
# Quelques paramètres importants :
# * training_resilience : combien de fois l'algorithme doit tourner lorsqu'il y a des valeurs qui n'ont pas encore convergé.
# * forbidden_variables_list : liste des variables qui n'ont pas besoin d'être encodées.
# * n_iterations_for_convergence : vérifie après n tours si les valeurs ont finalement convergé. 5 tours est largement suffisant dans la plupart des cas.
#
# La méthode train contient un argument important : sample_size. Il permet de prendre un échantillon de nos données (Big Data).

# %%
# sélection des 125 premières colonnes (les variables ne représentant pas les EVA)
df = data.iloc[:,:125]

# %%
# transformation des variables catégorielles : elles deviennent des chaines de caractère.
liste_var_cat = ['GroupeAppartenance', 'EtatCivil', 'Scolarite', 'prof_code', 'revenu_source', 'revenu_men',
                'habite', 'med1_code', 'med2_code', 'med3_code', 'med4_code', 'med5_code', 'med6_code', 'mv1_code',
                 'mv2_code', 'mv3_code', 'mv4_code', 'mv5_code', 'mv6_code', 'DXaxeIACTUEL_00', 'DXaxeIACTUEL_01',
                 'DXaxeIACTUEL_02', 'DXaxeIACTUEL_03', 'DXaxeIACTUEL_04', 'DXaxeIACTUEL_05', 'DXaxeIVIE_00', 'DXaxeIVIE_01',
                 'DXaxeIVIE_02', 'DXaxeIVIE_03', 'DXaxeIVIE_04', 'DXaxeIVIE_05', 'DXaxeIVIE_06',
                'DXaxeII_01', 'DXaxeII_02', 'DXaxeII_03', 'DXaxeII_04', 'DXaxeII_05']

def transform_colonne(dataset, colonne):
    for i in range(len(dataset[colonne])):
        if not math.isnan(dataset.loc[i, colonne]):
            dataset.loc[i, colonne] = str(dataset.loc[i, colonne])

for col in liste_var_cat:
    transform_colonne(df, col)

# %%
# imputation avec RandomForest. On précise les variables binaires (forbidden_features_list)
imputer = RandomForestImputer(data=df,
                              target_variable_name="GroupeAppartenance",
                              training_resilience=3, 
                              n_iterations_for_convergence=5,
                              forbidden_features_list=["Genre", 'men_conjoint',
                                                       'men_mere', 'men_pere', 'men_fratrie', 'men_enfants',
                                                       'mere_vie', 'pere_vie', 'separation', 'divorce', 'adopte',
                                                       'fam_accueil', 'DEPmereC', 'DEPmereP', 'DEPpereC',
                                                       'DEPpereP', 'DEPfrereC', 'DEPfrereP', 'DEPsoeurC',
                                                       'DEPsoeurP', 'MA_mereC', 'MA_mereP', 'MA_pereC',
                                                       'MA_pereP', 'MA_frereC', 'MA_frereP', 'MA_soeurC',
                                                       'MA_soeurP', 'SZmereC', 'SZfrereP', 'SZsoeurC',
                                                       'SZsoeurP', 'SUImereC', 'SUImereP', 'SUIpereC',
                                                       'SUIpereP', 'SUIfrereC', 'SUIfrereP', 'SUIsoeurC', 
                                                       'SUIsoeurP', 'T_SUImereC', 'T_SUImereP', 'T_SUIpereC',
                                                       'T_SUIpereP', 'T_SUIfrereC', 'T_SUIfrereP', 'T_SUIsoeurC',
                                                       'T_SUIsoeurP', 'ALCmereC', 'ALCmereP', 'ALCpereC',
                                                       'ALCpereP', 'ALCfrereC', 'ALCfrereP', 'ALCsoeurC',
                                                       'ALCsoeurP', 'ADmereC', 'ADmereP', 'ADpereC', 'ADperep',
                                                       'ADfrereC', 'ADfrereP', 'ADsoeurC', 'ADsoeurP',
                                                       'ALZmereC', 'ALZmereP', 'ALZpereC', 'ALZpereP',
                                                       'ALZfrereC', 'ALZfrereP', 'ALZsoeurC', 'ALZsoeurP', 
                                                       'TOCmereC', 'TOCmereP', 'TOCpereC', 'TOCpereP',
                                                       'TOCfrereC', 'TOCfrereP', 'TOCsoeurC', 'TOCsoeurP',
                                                       'Trouble_des_conduites' ],
                              ordinal_features_list=[])

imputer.set_ensemble_model_parameters(n_estimators=40, additional_estimators=10)
new_df = imputer.train(sample_size=0.3, path_to_save_dataset="df_no_nan.csv")
# Out:
# [DATA SAMPLING]: 100% |#########################################| Time: 0:00:00
# [ISOLATING SAMPLESWITH NO TARGET VALUE]: 100% |#################| Time: 0:00:00
# [PREDICTING FEATURE TYPE]: 100% |###############################| Time: 0:00:02
# [PREDICTING TARGET VARIABLETYPE]: 100% |########################| Time: 0:00:00
# [RETRIEVING NAN COORDINATES]: 100% |############################| Time: 0:00:00
# [MAKING INITIAL GUESSES]: 100% |################################| Time: 0:00:00
# [1/1-BUILDING RANDOM FOREST]: 100% |############################| Time: 0:00:00
# [1-FITTING AND EVALUATING MODEL]: 100% |########################| Time: 0:00:00
# [1-BUILDING PROXIMITY MATRIX TREES/OOB 60/0.63]: 100% |#########| Time: 0:00:01
# [1-COMPUTING WEIGHTED AVERAGES]: 100% |#########################| Time: 0:00:31
# [1-REPLACING MISSING VALUES]: 100% |############################| Time: 0:00:06
# [2/2-BUILDING RANDOM FOREST]: 100% |############################| Time: 0:00:00
# ...

# %%
# concaténation des données : on ajoute les variables fardeau 
# On remplace les valeurs 77 et 99 par Nan pour les variables fardeau.
datafardeau = pd.concat([new_df, data.iloc[:,125:145]], axis=1)
datafardeau.iloc[:,125:145] = datafardeau.iloc[:,125:145].replace(77,np.NAN).replace(99,np.NAN)

# %%
# suppression des colonnes avec seulement des valeurs nulles
variables_nan = list(datafardeau.columns[datafardeau.isna().all()])
datafardeau.drop(variables_nan, axis=1, inplace=True)

# %%
# Deuxième imputation : cette fois-ci on s'occupe des variables fardeau.
imputer = RandomForestImputer(data=datafardeau,
                              target_variable_name="GroupeAppartenance",
                              training_resilience=3, 
                              n_iterations_for_convergence=5,
                              forbidden_features_list=["Genre", 'men_conjoint',
                                                       'men_mere', 'men_pere', 'men_fratrie', 'men_enfants',
                                                       'mere_vie', 'pere_vie', 'separation', 'divorce', 'adopte',
                                                       'fam_accueil', 'DEPmereC', 'DEPmereP', 'DEPpereC',
                                                       'DEPpereP', 'DEPfrereC', 'DEPfrereP', 'DEPsoeurC',
                                                       'DEPsoeurP', 'MA_mereC', 'MA_mereP', 'MA_pereC',
                                                       'MA_pereP', 'MA_frereC', 'MA_frereP', 'MA_soeurC',
                                                       'MA_soeurP', 'SZmereC', 'SZfrereP', 'SZsoeurC',
                                                       'SZsoeurP', 'SUImereC', 'SUImereP', 'SUIpereC',
                                                       'SUIpereP', 'SUIfrereC', 'SUIfrereP', 'SUIsoeurC', 
                                                       'SUIsoeurP', 'T_SUImereC', 'T_SUImereP', 'T_SUIpereC',
                                                       'T_SUIpereP', 'T_SUIfrereC', 'T_SUIfrereP', 'T_SUIsoeurC',
                                                       'T_SUIsoeurP', 'ALCmereC', 'ALCmereP', 'ALCpereC',
                                                       'ALCpereP', 'ALCfrereC', 'ALCfrereP', 'ALCsoeurC',
                                                       'ALCsoeurP', 'ADmereC', 'ADmereP', 'ADpereC', 'ADperep',
                                                       'ADfrereC', 'ADfrereP', 'ADsoeurC', 'ADsoeurP',
                                                       'ALZmereC', 'ALZmereP', 'ALZpereC', 'ALZpereP',
                                                       'ALZfrereC', 'ALZfrereP', 'ALZsoeurC', 'ALZsoeurP', 
                                                       'TOCmereC', 'TOCmereP', 'TOCpereC', 'TOCpereP',
                                                       'TOCfrereC', 'TOCfrereP', 'TOCsoeurC', 'TOCsoeurP',
                                                       'Trouble_des_conduites' ],
                              ordinal_features_list=[])

imputer.set_ensemble_model_parameters(n_estimators=40, additional_estimators=10)
new_datafardeau = imputer.train(sample_size=0.3, path_to_save_dataset="df_no_nan.csv")
# Out:
# [DATA SAMPLING]: 100% |#########################################| Time: 0:00:00
# [ISOLATING SAMPLESWITH NO TARGET VALUE]: 100% |#################| Time: 0:00:00
# [PREDICTING FEATURE TYPE]: 100% |###############################| Time: 0:00:02
# [PREDICTING TARGET VARIABLETYPE]: 100% |########################| Time: 0:00:00
# [RETRIEVING NAN COORDINATES]: 100% |############################| Time: 0:00:00
# [MAKING INITIAL GUESSES]: 100% |################################| Time: 0:00:00
# [1/1-BUILDING RANDOM FOREST]: 100% |############################| Time: 0:00:00
# [1-FITTING AND EVALUATING MODEL]: 100% |########################| Time: 0:00:00
# [1-BUILDING PROXIMITY MATRIX TREES/OOB 50/0.63]: 100% |#########| Time: 0:00:01
# [1-COMPUTING WEIGHTED AVERAGES]: 100% |#########################| Time: 0:00:14
# [1-REPLACING MISSING VALUES]: 100% |############################| Time: 0:00:02
# [2/2-BUILDING RANDOM FOREST]: 100% |############################| Time: 0:00:00
# ...

# %% [markdown]
# ### Traitement des variables représentant les EVA

# %%
EVA = data.iloc[:,145:]
EVA = EVA.replace(99,np.NAN).replace(77,np.NAN).replace(88,np.NAN)

# %% [markdown]
# **Regroupement par type d'EVA**

# %%
def name_column(col):
    return col[:-3]

# %%
EVA_name = EVA.copy()
EVA_name.columns = list(map(name_column, EVA.columns))
eva_name = EVA_name.groupby(axis=1, level=0).sum()

# %% [markdown]
# **Regroupement par tranche d'age : 0-4, 5-9, 10-14, 15-19, 20-24, 25-29, 30-34, 35-39, 40-44, 45-49,
# 50-54, 55-59, 60-64, 65-69, 70-74, 75-79, 80-84, 85-89, 90-94, 95-99**

# %% [raw]
# def age_column(col):
#     return col[-2:]

# %% [raw]
# EVA_age = EVA.copy()
# EVA_age.columns = list(map(age_column, EVA.columns))
# eva_age = EVA_age.groupby(axis=1, level=0).sum()

# %% [raw]
# age_agg = ['0-4', '05-9', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39', '40-44', '45-49', '50-54', '55-59', '60-64',
#            '65-69', '70-74', '75-79', '80-84', '85-89', '90-94', '95-99']

# %% [raw]
# eva_age.columns = np.repeat(age_agg,5).tolist()
# eva_age_agg = eva_age.groupby(axis=1, level=0).sum()

# %% [markdown]
# **Sommer au total**

# %%
EVA_somme = EVA.copy()
eva_somme = EVA_somme.sum(axis=1)
eva_somme.name = 'total'

# %% [markdown]
# **Type d'EVA + total**

# %%
# Regroupement des sommes
eva = pd.concat([eva_name, eva_somme], axis=1)

# %% [raw]
# # Regroupement des sommes
# eva = pd.concat([eva_name, eva_age_agg, eva_somme], axis=1)

# %%
# Division par l'age de l'individu
eva = eva.div(data['Age'], axis=0)

# %% [markdown]
# ### Création de notre jeu de données dataset

# %%
# concaténation : on ajoute le dataframe eva. 
dataset = pd.concat([new_datafardeau, eva], axis=1)

# %%
# Suppression de la variable TStotal
dataset.drop('TStotal', axis=1, inplace=True)

# %%
# suppression des variables avec une seule valeur.
liste_var_1valeur = dataset.columns[dataset.nunique() == 1]
dataset.drop(liste_var_1valeur, axis=1, inplace=True)

# %%
# Création de nouvelles variables à partir des variables "Diagnostic"
# somme des diagnostics divisé par l'age
dataset['DiagnosticActuel/Age'] = (dataset[['DXaxeIACTUEL_00', 'DXaxeIACTUEL_01', 'DXaxeIACTUEL_02','DXaxeIACTUEL_03',
                                            'DXaxeIACTUEL_04',
                                            'DXaxeIACTUEL_05']].astype('float') > 0).sum(axis=1) / dataset['Age']
dataset['DiagnosticVie/Age'] = (dataset[['DXaxeIVIE_00', 'DXaxeIVIE_01', 'DXaxeIVIE_02', 'DXaxeIVIE_03', 'DXaxeIVIE_04',
                                         'DXaxeIVIE_05', 'DXaxeIVIE_06']].astype('float') > 0).sum(axis=1) / dataset['Age']

dataset['DiagnosticAXEII/Age'] = (dataset[['DXaxeII_01', 'DXaxeII_02', 'DXaxeII_03', 'DXaxeII_04',
                                           'DXaxeII_05']] != '100.0').sum(axis=1) / dataset['Age']

# Binarisation : diagnostic ou pas ?
dataset['DXaxeIACTUEL_00_YN'] = (dataset['DXaxeIACTUEL_00'].astype('float') > 0).astype(int)
dataset['DXaxeIACTUEL_01_YN'] = (dataset['DXaxeIACTUEL_01'].astype('float') > 0).astype(int)
dataset['DXaxeIACTUEL_02_YN'] = (dataset['DXaxeIACTUEL_02'].astype('float') > 0).astype(int)
dataset['DXaxeIACTUEL_03_YN'] = (dataset['DXaxeIACTUEL_03'].astype('float') > 0).astype(int)
dataset['DXaxeIACTUEL_04_YN'] = (dataset['DXaxeIACTUEL_04'].astype('float') > 0).astype(int)
dataset['DXaxeIACTUEL_05_YN'] = (dataset['DXaxeIACTUEL_05'].astype('float') > 0).astype(int)

dataset['DXaxeIVIE_00_YN'] = (dataset['DXaxeIVIE_00'].astype('float') > 0).astype(int)
dataset['DXaxeIVIE_01_YN'] = (dataset['DXaxeIVIE_01'].astype('float') > 0).astype(int)
dataset['DXaxeIVIE_02_YN'] = (dataset['DXaxeIVIE_02'].astype('float') > 0).astype(int)
dataset['DXaxeIVIE_03_YN'] = (dataset['DXaxeIVIE_03'].astype('float') > 0).astype(int)
dataset['DXaxeIVIE_04_YN'] = (dataset['DXaxeIVIE_04'].astype('float') > 0).astype(int)
dataset['DXaxeIVIE_05_YN'] = (dataset['DXaxeIVIE_05'].astype('float') > 0).astype(int)
dataset['DXaxeIVIE_06_YN'] = (dataset['DXaxeIVIE_06'].astype('float') > 0).astype(int)

dataset['DXaxeII_01_YN'] = (dataset['DXaxeII_01'] != '100.0').astype(int)
dataset['DXaxeII_02_YN'] = (dataset['DXaxeII_02'] != '100.0').astype(int)
dataset['DXaxeII_03_YN'] = (dataset['DXaxeII_03'] != '100.0').astype(int)
dataset['DXaxeII_04_YN'] = (dataset['DXaxeII_04'] != '100.0').astype(int)
dataset['DXaxeII_05_YN'] = (dataset['DXaxeII_05'] != '100.0').astype(int)

# création des dummies (pas de distinction entre les diagnostics 1,2,3,4,5,6)
serie1 = pd.Series(dataset[['DXaxeIACTUEL_00', 'DXaxeIACTUEL_01', 'DXaxeIACTUEL_02', 'DXaxeIACTUEL_03', 
                          'DXaxeIACTUEL_04', 'DXaxeIACTUEL_05']].values.tolist())
dataset = pd.concat([(pd.get_dummies(serie1.apply(pd.Series).stack()).sum(level=0) > 0).astype(int).add_prefix('DXaxeIACTUEL_'), dataset], axis=1)

serie2 = pd.Series(dataset[['DXaxeIVIE_00', 'DXaxeIVIE_01', 'DXaxeIVIE_02', 'DXaxeIVIE_03', 'DXaxeIVIE_04',
                   'DXaxeIVIE_05', 'DXaxeIVIE_06']].values.tolist())
dataset = pd.concat([(pd.get_dummies(serie2.apply(pd.Series).stack()).sum(level=0) > 0).astype(int).add_prefix('DXaxeIVIE_'), dataset], axis=1)

serie3 = pd.Series(dataset[['DXaxeII_01', 'DXaxeII_02', 'DXaxeII_03', 'DXaxeII_04', 'DXaxeII_05']].values.tolist())
dataset = pd.concat([(pd.get_dummies(serie3.apply(pd.Series).stack()).sum(level=0) > 0).astype(int).add_prefix('DXaxeII_'), dataset], axis=1)

# suppression des variables "Diagnostic"
var_diagnostics = ['DXaxeIACTUEL_00', 'DXaxeIACTUEL_01', 'DXaxeIACTUEL_02', 'DXaxeIACTUEL_03', 'DXaxeIACTUEL_04', 
                  'DXaxeIACTUEL_05', 'DXaxeIVIE_00', 'DXaxeIVIE_01', 'DXaxeIVIE_02', 'DXaxeIVIE_03', 'DXaxeIVIE_04',
                   'DXaxeIVIE_05', 'DXaxeIVIE_06', 'DXaxeII_01', 'DXaxeII_02', 'DXaxeII_03', 'DXaxeII_04', 'DXaxeII_05'
                  ]
dataset.drop(var_diagnostics, axis=1, inplace=True)

# %%
# Notre variable GroupeAppartenance (variable à prédire) est désormais en dernière position.
colonne = dataset.pop('GroupeAppartenance')
dataset.insert(437, "GroupeAppartenance", colonne)

# %% [markdown]
# Traditionnellement, pour établir s’il existe un effet entre les deux variables qualitatives croisées dans un tableau de contigence, on utilise le test du Khi2. Le test V de Cramer permet de comparer l’intensité du lien entre les deux variables étudiées.

# %%
# trouver les corrélations les plus fortes entre les variables (test de Cramer)

# %% [raw]
# corr = dataset.corr().abs().where(np.triu(np.ones(dataset.corr().shape), k=1).astype(np.bool)).stack().sort_values(ascending=False)
# var_correlation = set(corr[corr > 0.9].index.get_level_values(1))
# dataset.drop(var_correlation, axis=1, inplace=True)

# %% [markdown]
# ### Modélisation 1 : classification multiclasse
#
# **On procède à une classification multiclasse.
# On a trois classes : 0 groupe pop / 1 tentative de suicide / 2 décès suicide**

# %%
# séparation des variables prédictives (X) et à prédire (y)
X = dataset.iloc[:,:-1]
y = dataset.iloc[:,-1]

# %%
# on identifie les variables catégorielles, numériques et binaires
categorical_columns = X.select_dtypes(['object']).columns
numerical_columns = X.drop(categorical_columns, axis=1).columns[X.drop(categorical_columns, axis=1).nunique() > 2].tolist()
binary_columns = X.drop(categorical_columns, axis=1).drop(numerical_columns, axis=1).columns.tolist()

numerical_columns.append('fardeau80_84')
binary_columns.remove('fardeau80_84')

# %% [markdown]
# On crée un pipeline : plusieurs étapes sont à respecter.
# * Préparation des variables (en fonction de leur type)
#     * Variables catégorielles : encodage
#     * Variables numériques : suppression des variables avec une faible variance; normalisation
#     * Variables binaires : RAS => remainder='passthrough'
# * Modèle

# %%
# préparation des variables numériques
trans_numerical = Pipeline([('variance', VarianceThreshold(threshold=0.2)),('norm', MinMaxScaler())])

# %%
# séparation entre les variables numériques et catégorielles
transformer = ColumnTransformer([('onehot', OneHotEncoder(sparse=False, handle_unknown='ignore'), categorical_columns),
                               ('numerical', trans_numerical, numerical_columns)], 
                                remainder='passthrough')

# %%
model = LGBMClassifier(class_weight='balanced')

# %% [markdown]
# The ‘balanced’ mode uses the values of y to automatically adjust weights inversely proportional to class frequencies in the input data as n_samples / (n_classes * np.bincount(y))

# %%
# création du pipeline
pipeline = Pipeline([('trans', transformer), ('sample', SMOTE()), ('model', model)])

# %% [markdown]
# A problem with imbalanced classification is that there are too few examples of the minority class for a model to effectively learn the decision boundary. One way to solve this problem is to oversample the examples in the minority class. This can be achieved by simply duplicating examples from the minority class in the training dataset prior to fitting a model. This can balance the class distribution but does not provide any additional information to the model. An improvement on duplicating examples from the minority class is to synthesize new examples from the minority class. This is a type of data augmentation for tabular data and can be very effective.
# SMOTE works by selecting examples that are close in the feature space, drawing a line between the examples in the feature space and drawing a new sample at a point along that line. Specifically, a random example from the minority class is first chosen. Then k of the nearest neighbors for that example are found (typically k=5). A randomly selected neighbor is chosen and a synthetic example is created at a randomly selected point between the two examples in feature space.

# %%
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

# %%
# évaluation du modèle : accuracy
results = cross_val_score(pipeline, X, y, cv=kfold, scoring='accuracy')
results.mean()
# Out:
# 0.7500991609458428

# %%
# afficher le rapport de classification pour le jeu de test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
pipeline.fit(X_train, y_train)
X_test_resampled, y_test_resampled = SMOTE().fit_resample(X_test, y_test)
print(classification_report(y_test_resampled, pipeline.predict(X_test_resampled)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.67      0.71        63
#          1.0       0.45      0.30      0.36        63
#          2.0       0.61      0.89      0.72        63
#
#     accuracy                           0.62       189
#    macro avg       0.61      0.62      0.60       189
# weighted avg       0.61      0.62      0.60       189

# %% [markdown]
# The reported averages include macro average (averaging the unweighted mean per label), weighted average (averaging the support-weighted mean per label), and sample average (only for multilabel classification). Micro average (averaging the total true positives, false negatives and false positives) is only shown for multi-label or multi-class with a subset of classes, because it corresponds to accuracy otherwise and would be the same for all metrics.
#
# Support is the number of actual occurrences of the class in the specified dataset. Imbalanced support in the training data may indicate structural weaknesses in the reported scores of the classifier and could indicate the need for stratified sampling or rebalancing. Support doesn’t change between models but instead diagnoses the evaluation process.

# %%
# matrice de confusion pour le jeu de test
confusion_matrix(y_test_resampled, pipeline.predict(X_test_resampled))
# Out:
# array([[42, 19,  2],
#        [10, 19, 34],
#        [ 3,  4, 56]], dtype=int64)

# %%
# roc auc pour le jeu de test
roc_auc_score(y_test_resampled, pipeline.predict_proba(X_test_resampled), average="weighted", multi_class='ovo' )
# Out:
# 0.8330393885949441

# %% [markdown]
# "Permutation feature importance" est une technique qui permet de calculer les scores d'importance relative.
# 1- On entraine le modèle sur le jeu de données.
# 2- Le modèle est utilisé pour faire des prédictions. On ne prend pas en compte une variable.
# On fait cela pour chaque variable.
# On répète l'opération plusieurs fois (3, 5, 10 fois). Enfin on fait la moyenne de ces résultats pour obtenir l'importance moyenne.
#
# The estimator is required to be a fitted estimator. X can be the data set used to train the estimator or a hold-out set. The permutation importance of a feature is calculated as follows. First, a baseline metric, defined by scoring, is evaluated on a (potentially different) dataset defined by the X. Next, a feature column from the validation set is permuted and the metric is evaluated again. The permutation importance is defined to be the difference between the baseline metric and metric from permutating the feature column.
#
# Permutation feature importance is a model inspection technique that can be used for any fitted estimator when the data is tabular. This is especially useful for non-linear or opaque estimators. The permutation feature importance is defined to be the decrease in a model score when a single feature value is randomly shuffled 1. This procedure breaks the relationship between the feature and the target, thus the drop in the model score is indicative of how much the model depends on the feature. This technique benefits from being model agnostic and can be calculated many times with different permutations of the feature.

# %%
importances = permutation_importance(pipeline, X, y, scoring='accuracy').importances_mean

# %%
# zipper les noms des colonnes avec les importances
list_importances = list(zip(X.columns, importances))
sort_importances = sorted(list_importances, key=lambda x: x[1], reverse=True)[:20]

# %%
# afficher les variables les plus importantes
plt.figure(figsize=(15,10))
plt.barh([sort_importances[19-i][0] for i in range(len(sort_importances))], 
         [sort_importances[19-i][1] for i in range(len(sort_importances))]) 
plt.show()

# %%
# nouvelle création du pipeline mais adaptée à SHAP
X_copy = X.copy()
y_copy = y.copy()

# encodage des variables catégorielles
X_cat_trans = pd.get_dummies(X_copy[categorical_columns])

# variancethreshold + minmaxscaler pour les variables numériques
col_num = VarianceThreshold(threshold=0.2).fit(X_copy[numerical_columns]).get_support()
X_num_trans = X_copy[X_copy[numerical_columns].columns[col_num]]
X_num_trans = pd.DataFrame(MinMaxScaler().fit_transform(X_num_trans), columns=X_num_trans.columns)
X_num_trans

# concaténation
X_trans = pd.concat([X_cat_trans, X_num_trans, X[binary_columns]], axis=1)

# Resample
X_resampled, y_resampled = SMOTE().fit_resample(X_trans, y)

# modèle LGBM
model = LGBMClassifier(class_weight='balanced')

model.fit(X_resampled, y_resampled)
# Out:
# LGBMClassifier(class_weight='balanced')

# %%
# afficher les variables les plus importantes
shap.initjs()

explainer = shap.TreeExplainer(model) #If LGBM, RF or XGB

shap_values = explainer.shap_values(X_trans)


shap.summary_plot(shap_values, X_trans, plot_type="bar")
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %% [markdown]
# ### Modélisation 2 : classification binaire (classes 0/2)
#
# **On procède à une classification binaire.
# On a deux classes : 0 groupe pop / 2 décès suicide**

# %%
dataset_2 = dataset[dataset['GroupeAppartenance'] != '1.0']
dataset_2.reset_index(drop=True, inplace=True)

# %%
# séparation des variables prédictives (X) et à prédire (y)
X = dataset_2.iloc[:,:-1]
y = dataset_2.iloc[:,-1]

# %%
# on identifie les variables catégorielles, numériques et binaires
categorical_columns = X.select_dtypes(['object']).columns
numerical_columns = X.drop(categorical_columns, axis=1).columns[X.drop(categorical_columns, axis=1).nunique() > 2].tolist()
binary_columns = X.drop(categorical_columns, axis=1).drop(numerical_columns, axis=1).columns.tolist()

numerical_columns.append('fardeau80_84')
binary_columns.remove('fardeau80_84')

# %% [markdown]
# On crée un pipeline : plusieurs étapes sont à respecter.
# * Préparation des variables (en fonction de leur type)
#     * Variables catégorielles : encodage
#     * Variables numériques : suppression des variables avec une faible variance; normalisation
#     * Variables binaires : RAS => remainder='passthrough'
# * Modèle

# %%
# préparation des variables numériques
trans_numerical = Pipeline([('variance', VarianceThreshold(threshold=0.2)),('norm', MinMaxScaler())])

# %%
# séparation entre les variables numériques et catégorielles
transformer = ColumnTransformer([('onehot', OneHotEncoder(sparse=False, handle_unknown='ignore'), categorical_columns),
                               ('numerical', trans_numerical, numerical_columns)], 
                                remainder='passthrough')

# %%
model = LGBMClassifier(class_weight='balanced')

# %% [markdown]
# The ‘balanced’ mode uses the values of y to automatically adjust weights inversely proportional to class frequencies in the input data as n_samples / (n_classes * np.bincount(y))

# %%
# création du pipeline
pipeline = Pipeline([('trans', transformer), ('sample', SMOTE()), ('model', model)])

# %% [markdown]
# A problem with imbalanced classification is that there are too few examples of the minority class for a model to effectively learn the decision boundary. One way to solve this problem is to oversample the examples in the minority class. This can be achieved by simply duplicating examples from the minority class in the training dataset prior to fitting a model. This can balance the class distribution but does not provide any additional information to the model. An improvement on duplicating examples from the minority class is to synthesize new examples from the minority class. This is a type of data augmentation for tabular data and can be very effective.
# SMOTE works by selecting examples that are close in the feature space, drawing a line between the examples in the feature space and drawing a new sample at a point along that line. Specifically, a random example from the minority class is first chosen. Then k of the nearest neighbors for that example are found (typically k=5). A randomly selected neighbor is chosen and a synthetic example is created at a randomly selected point between the two examples in feature space.

# %%
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

# %%
# évaluation du modèle : accuracy
results = cross_val_score(pipeline, X, y, cv=kfold, scoring='accuracy')
results.mean()
# Out:
# 0.9177155655095186

# %%
# afficher le rapport de classification pour le jeu de test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
pipeline.fit(X_train, y_train)
X_test_resampled, y_test_resampled = SMOTE().fit_resample(X_test, y_test)
print(classification_report(y_test_resampled, pipeline.predict(X_test_resampled)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.93      0.93        61
#          2.0       0.93      0.92      0.93        61
#
#     accuracy                           0.93       122
#    macro avg       0.93      0.93      0.93       122
# weighted avg       0.93      0.93      0.93       122

# %%
# matrice de confusion pour le jeu de test
confusion_matrix(y_test_resampled, pipeline.predict(X_test_resampled))
# Out:
# array([[57,  4],
#        [ 5, 56]], dtype=int64)

# %%
# roc auc pour le jeu de test
roc_auc_score(y_test_resampled, pd.DataFrame(pipeline.predict_proba(X_test_resampled))[1].values)
# Out:
# 0.9677506046761624

# %%
importances = permutation_importance(pipeline, X, y, scoring='accuracy').importances_mean

# %%
# zipper les noms des colonnes avec les importances
list_importances = list(zip(X.columns, np.abs(importances)))
sort_importances = sorted(list_importances, key=lambda x: x[1], reverse=True)[:20]

# %%
# afficher les variables les plus importantes
plt.figure(figsize=(15,10))
plt.barh([sort_importances[19-i][0] for i in range(len(sort_importances))], 
         [sort_importances[19-i][1] for i in range(len(sort_importances))]) 
plt.show()

# %%
# nouvelle création du pipeline mais adaptée à SHAP
X_copy = X.copy()
y_copy = y.copy()

# encodage des variables catégorielles
X_cat_trans = pd.get_dummies(X_copy[categorical_columns])

# variancethreshold + minmaxscaler pour les variables numériques
col_num = VarianceThreshold(threshold=0.2).fit(X_copy[numerical_columns]).get_support()
X_num_trans = X_copy[X_copy[numerical_columns].columns[col_num]]
X_num_trans = pd.DataFrame(MinMaxScaler().fit_transform(X_num_trans), columns=X_num_trans.columns)
X_num_trans

# concaténation
X_trans = pd.concat([X_cat_trans, X_num_trans, X[binary_columns]], axis=1)

# Resample
X_resampled, y_resampled = SMOTE().fit_resample(X_trans, y)

# modèle LGBM
model = LGBMClassifier(class_weight='balanced')

model.fit(X_resampled, y_resampled)
# Out:
# LGBMClassifier(class_weight='balanced')

# %%
# afficher les variables les plus importantes
shap.initjs()

explainer = shap.TreeExplainer(model) #If LGBM, RF or XGB

shap_values = explainer.shap_values(X_trans)


shap.summary_plot(shap_values, X_trans, plot_type="bar")
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %% [raw]
# shap.plots.scatter(shap_values[:,"Age"], color=shap_values)

# %% [raw]
# shap.plots.beeswarm(shap_values)

# %% [raw]
# **SHAP**

# %% [raw]
# # afficher les variables les plus importantes
# shap.initjs()
# X_shap=shap.sample(X, 1000)
#
# explainer = shap.TreeExplainer(model) #If LGBM, RF or XGB
#
# # explainer = shap.KernelExplainer(predict, X_shap[used_var]) #IF ZGP
#
# shap_values = explainer.shap_values(X_shap)

# %% [raw]
# shap.summary_plot(shap_values, X_shap, plot_type="bar")

# %% [markdown]
# ### Modélisation 3 : classification multiclasse avec FLAML
#
# **On procède à une classification multiclasse.
# On a trois classes : 0 groupe pop / 1 tentative de suicide / 2 décès suicide**

# %%
# séparation des variables prédictives (X) et à prédire (y)
X = dataset.iloc[:,:-1]
y = dataset.iloc[:,-1]

# %% [markdown]
# FLAML is a lightweight Python library that finds accurate machine learning models automatically, efficiently and economically. It frees users from selecting learners and hyperparameters for each learner. It is fast and economical. The simple and lightweight design makes it easy to extend, such as adding customized learners or metrics. FLAML is powered by a new, cost-effective hyperparameter optimization and learner selection method invented by Microsoft Research. FLAML leverages the structure of the search space to choose a search order optimized for both cost and error. For example, the system tends to propose cheap configurations at the beginning stage of the search, but quickly moves to configurations with high model complexity and large sample size when needed in the later stage of the search. For another example, it favors cheap learners in the beginning but penalizes them later if the error improvement is slow. The cost-bounded search and cost-based prioritization make a big difference in the search efficiency under budget constraints.
#
# Advantages
# For classification and regression tasks, find quality models with lower computational resources.
# Users can choose their desired customizability: minimal customization (computational resource budget), medium customization (e.g., scikit-style learner, search space and metric), full customization (arbitrary training and evaluation code).
# Allow human guidance in hyperparameter tuning to respect prior on certain subspaces but also able to explore other subspaces.

# %%
# création de automl
automl = AutoML()

# %%
# paramètres de automl
automl_settings = {
    "time_budget": 180,  # in seconds
    "metric": 'accuracy',
    "task": 'classification',
    "n_jobs": -1,
    "estimator_list": ['lgbm', 'xgboost', 'catboost', 'rf', 'extra_tree'],
    "eval_method": 'cv',
    "n_splits": 5,
    "verbose": 0
    
}

# %% [markdown]
# metrics : ‘accuracy’, ‘roc_auc’, ‘f1’, ‘micro_f1’, ‘macro_f1’, ‘log_loss’, ‘mae’, ‘mse’, ‘r2’

# %%
# entrainement 
automl.fit(X_train=X, y_train=y, **automl_settings)

# %%
# meilleur estimateur
automl.best_estimator

# %%
# meilleure configuration
automl.best_config

# %%
# meilleur modèle pour chaque estimateur
for i, model in enumerate(automl_settings['estimator_list']):
    print('model {} : {} '.format(i, model))
    print(automl.best_model_for_estimator(model))

# %%
# on identifie les variables catégorielles, numériques et binaires
intfloat_columns = X.select_dtypes(['int64', 'float64']).columns

categorical_columns = X.select_dtypes(['object']).columns
binary_columns = intfloat_columns[:83][X[intfloat_columns[:83]].nunique() <= 2]
numerical_columns = X[intfloat_columns].drop(binary_columns, axis=1).columns

# %%
# préparation des variables numériques
trans_numerical = Pipeline([('variance', VarianceThreshold(threshold=0.2)),('norm', MinMaxScaler())])

# %%
# séparation entre les variables numériques et catégorielles
transformer = ColumnTransformer([('onehot', OneHotEncoder(sparse=False, handle_unknown='ignore'), categorical_columns),
                               ('numerical', trans_numerical, numerical_columns)], 
                                remainder='passthrough')

# %%
model = automl.model

# %%
# création du pipeline
pipeline = Pipeline([('trans', transformer), ('model', model)])

# %%
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

# %%
# évaluation du modèle : accuracy
results = cross_val_score(pipeline, X, y, cv=kfold, scoring='accuracy')
results.mean()

# %%
# afficher le rapport de classification pour le jeu de test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
pipeline.fit(X_train, y_train)
print(classification_report(y_test, pipeline.predict(X_test)))

# %%
# matrice de confusion pour le jeu de test
confusion_matrix(y_test, pipeline.predict(X_test))

# %%
# roc auc pour le jeu de test
roc_auc_score(y_test, pipeline.predict_proba(X_test), average="weighted", multi_class='ovo' )

# %%
importances = permutation_importance(pipeline, X, y, scoring='accuracy').importances_mean

# %%
# zipper les noms des colonnes avec les importances
list_importances = list(zip(X.columns, importances))
sort_importances = sorted(list_importances, key=lambda x: x[1], reverse=True)[:20]

# %%
# afficher les variables les plus importantes
plt.figure(figsize=(15,10))
plt.barh([sort_importances[19-i][0] for i in range(len(sort_importances))], 
         [sort_importances[19-i][1] for i in range(len(sort_importances))]) 
plt.show()

# %%
# nouvelle création du pipeline mais adaptée à SHAP
X_copy = X.copy()
y_copy = y.copy()

# encodage des variables catégorielles
X_cat_trans = pd.get_dummies(X_copy[categorical_columns])

# variancethreshold + minmaxscaler pour les variables numériques
col_num = VarianceThreshold(threshold=0.2).fit(X_copy[numerical_columns]).get_support()
X_num_trans = X_copy[numerical_columns[col_num]]
X_num_trans = pd.DataFrame(MinMaxScaler().fit_transform(X_num_trans), columns=X_num_trans.columns)
X_num_trans

# concaténation
X_trans = pd.concat([X_cat_trans, X_num_trans, X[binary_columns]], axis=1)

X_resampled, y_resampled = SMOTE().fit_resample(X_trans, y)

# modèle LGBM
model = LGBMClassifier(class_weight='balanced')

model.fit(X_resampled, y_resampled)

# %%
# afficher les variables les plus importantes
shap.initjs()

explainer = shap.TreeExplainer(model) #If LGBM, RF or XGB

shap_values = explainer.shap_values(X_trans)


shap.summary_plot(shap_values, X_trans, plot_type="bar")

# %% [markdown]
# ### Modélisation 4 : classification multiclasse avec TPOT
#
# **On procède à une classification multiclasse.
# On a trois classes : 0 groupe pop / 1 tentative de suicide / 2 décès suicide**

# %%
# séparation des variables prédictives (X) et à prédire (y)
X = dataset.iloc[:,:-1]
y = dataset.iloc[:,-1]

# %%
# séparation en jeux d'entrainement et de test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# TPOT is a Python Automated Machine Learning tool that optimizes machine learning pipelines using genetic programming.
# TPOT will automate the most tedious part of machine learning by intelligently exploring thousands of possible pipelines to find the best one for your data.
# Once TPOT is finished searching (or you get tired of waiting), it provides you with the Python code for the best pipeline it found so you can tinker with the pipeline from there.

# %%
tpot_config = {
    'sklearn.ensemble.RandomForestClassifier': {
    },

    'sklearn.ensemble.GradientBoostingClassifier': {
    },

    'sklearn.ensemble.ExtraTreesClassifier': {
    },
    
    'lightgbm.LGBMClassifier':{
        
    }
}

# %%
# création du pipeline
pipeline_optimizer = TPOTClassifier(scoring='balanced_accuracy', n_jobs=-1, max_time_mins=2160, random_state=0, 
                                   config_dict=tpot_config, verbosity=1)

# %%
# entrainement du pipeline
pipeline_optimizer.fit(X_train, y_train)

# %%
# score
pipeline_optimizer.score(X_test, y_test)

# %%
# export du pipeline 
pipeline_optimizer.export('tpot_exported_pipeline.py')
